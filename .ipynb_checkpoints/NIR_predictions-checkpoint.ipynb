# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import glob
import os
import import_ipynb
from simca import SIMCAModel, SIMCAClassModel
# Out:
# Class 0 inside: [ True  True  True] ODcrit 3.412856676496038e-29 SDcrit 21.52636704670711
# Class 1 inside: [False  True  True] ODcrit 3.695354969633676e-29 SDcrit 22.497912128895308

# %%
xvoo_none_nir_path = r"data/Replicate_011_20251205/Replicate_011_20251205/xvoo_none/NIR"

xvoo_none_files = sorted(glob.glob(os.path.join(xvoo_none_nir_path, "*.csv")))

print(f"Number of XVOO_NONE NIR measurements: {len(xvoo_none_files)}")

xvoo_none_raw = []

for i, fpath in enumerate(xvoo_none_files):
    df = pd.read_csv(fpath)

    if i == 0:
        wavelengths = df["x"].values

    xvoo_none_raw.append(df["y"].values)

xvoo_none_raw = np.array(xvoo_none_raw)

print("evoo_none_spectra_raw shape:", xvoo_none_raw.shape)

plt.figure(figsize=(8, 4))
for i in range(len(xvoo_none_raw)):
    plt.plot(wavelengths, xvoo_none_raw[i], alpha=0.4)

plt.xlabel("Wavelength (nm)")
plt.ylabel("Intensity")
plt.title("Raw NIR spectra – XVOO_NONE")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Number of XVOO_NONE NIR measurements: 10
# evoo_none_spectra_raw shape: (10, 228)

# %%
wr_xvoo_none_file = r"data/Replicate_011_20251205/Replicate_011_20251205/xvoo_none/wr/NIR_WR.csv"

wr_xvoo_none_df = pd.read_csv(wr_xvoo_none_file)

wl_xvoo_none_wr = wr_xvoo_none_df["x"].values
I_xvoo_none_wr = wr_xvoo_none_df["y"].values

print("WR shape:", wr_xvoo_none_df.shape)

assert np.allclose(wavelengths, wl_xvoo_none_wr), "XVOO_NONE and WR wavelengths do NOT match!"

plt.figure(figsize=(8, 4))
plt.plot(wl_xvoo_none_wr, I_xvoo_none_wr, color='green')
plt.xlabel("Wavelength (nm)")
plt.ylabel("Intensity")
plt.title("White Reference (WR) – NIR")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# WR shape: (228, 2)

# %%
xvoo_none_norm = xvoo_none_raw / I_xvoo_none_wr

plt.figure(figsize=(8, 4))

for i in range(len(xvoo_none_norm)):
    plt.plot(wavelengths, xvoo_none_norm[i], alpha=0.4)

plt.xlabel("Wavelength (nm)")
plt.ylabel("Normalized intensity (I / I_WR)")
plt.title("Normalized NIR spectra – xvoo_none")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
xvoo_none_norm.shape
# Out:
# (10, 228)

# %%
X = xvoo_none_norm
y = np.array(["XVOO_NONE"] * X.shape[0])

simca = SIMCAModel(alpha=0.05, default_n_components=None)

comp_grid = list(range(1, min(10, X.shape[1])+1))
best_components = simca.tune_num_components(
    X, y,
    comp_grid=comp_grid,
    cv=5,
    mode='rigorous',    # 'rigorous', 'compliant'
    rule='sim',         # 'sim', 'alt', 'ci', 'dd'
    od_method='percentile',    # 'percentile', 'jackson', 'box'
    sd_method='f'       # 'f', 'chi2', 'percentile'
)
print("Optimal number of PCA components per class:", best_components)

simca.fit(X, y, n_components=list(best_components.values())[0])

simca.set_thresholds_all(od_method='percentile', sd_method='f')

results = simca.predict(X, rule='sim')
res = results['XVOO_NONE']

print("SIMCA thresholds:")
print("ODcrit:", res.get('ODcrit', None))
print("SDcrit:", res.get('SDcrit', None))
print("Inside class (True = sample accepted):", res['inside'])

plt.figure(figsize=(8,5))
colors = np.where(res['inside'], 'blue', 'red')
plt.scatter(res['SD'], res['OD'], c=colors, edgecolor='k')
plt.axhline(simca.class_models['XVOO_NONE'].thresholds['ODcrit'], color='green', linestyle='--', label='OD threshold')
plt.axvline(simca.class_models['XVOO_NONE'].thresholds['SDcrit'], color='orange', linestyle='--', label='SD threshold')
plt.xlabel("Score Distance (SD)")
plt.ylabel("Orthogonal Distance (OD)")
plt.title("SIMCA - XVOO_NONE")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Optimal number of PCA components per class: {'XVOO_NONE': 1}
# SIMCA thresholds:
# ODcrit: 0.006501911864453147
# SDcrit: 5.62909053211915
# Inside class (True = sample accepted): [ True  True  True  True  True  True False  True  True  True]

# %%
# plt.figure(figsize=(12,10))

# rules = {'SIMCA':'sim', 'Alt-SIMCA':'alt', 'CI-SIMCA':'ci', 'DD-SIMCA':'dd'}
# for i, (name, rule) in enumerate(rules.items(), 1):
#     res = simca.predict(X, rule=rule)['XVOO_NONE']
    
#     colors = ['blue' if flag else 'red' for flag in res['inside']]
    
#     plt.subplot(2,2,i)
#     plt.scatter(res['SD'], res['OD'], c=colors, edgecolor='k')
#     plt.axhline(simca.class_models['XVOO_NONE'].thresholds['ODcrit'], color='green', linestyle='--', label='OD threshold')
#     plt.axvline(simca.class_models['XVOO_NONE'].thresholds['SDcrit'], color='orange', linestyle='--', label='SD threshold')
#     plt.title(name)
#     plt.xlabel("SD")
#     plt.ylabel("OD")
#     plt.grid(True)

# plt.tight_layout()
# plt.show()

# %%
base_folder = r"C:\Users\Lenovo\Documents\GitHub\aiSpectra\data\Replicate_011_20251205\Replicate_011_20251205\xvoo_mix"
mixtures = ["xvoo_oo10", "xvoo_oo20", "xvoo_oo30", "xvoo_oo40", "xvoo_oo60", "xvoo_oo70", "xvoo_oo80"]

wr_file = os.path.join(base_folder, "wr", "NIR_WR.csv")
wr = pd.read_csv(wr_file).iloc[:, 0].values

X_list = []
y_list = []

for mix in mixtures:
    nir_folder = os.path.join(base_folder, mix, "NIR")
    if not os.path.exists(nir_folder):
        print(f"Upozorenje: folder ne postoji {nir_folder}, preskačem...")
        continue
    files = [f for f in os.listdir(nir_folder) if f.endswith(".csv")]
    for f in files:
        df = pd.read_csv(os.path.join(nir_folder, f))
        spectrum = df.iloc[:, 0].values
        spectrum_norm = spectrum / wr
        X_list.append(spectrum_norm)
        y_list.append(mix)

for i in range(xvoo_none_norm.shape[0]):
    X_list.append(xvoo_none_norm[i])
    y_list.append("XVOO_NONE")

X_all_norm = np.array(X_list)
y_all = np.array(y_list)

print("Shape X_all_norm:", X_all_norm.shape)
print("Shape y_all:", y_all.shape)
# Out:
# Shape X_all_norm: (220, 228)
# Shape y_all: (220,)

# %%
results_mix = simca.predict(X_all_norm, rule='sim')
res_mix = results_mix['XVOO_NONE']

ODcrit = simca.class_models['XVOO_NONE'].thresholds['ODcrit']
SDcrit = simca.class_models['XVOO_NONE'].thresholds['SDcrit']

print("OD threshold:", ODcrit)
print("SD threshold:", SDcrit)

inside = res_mix['inside']
for i, accepted in enumerate(inside):
    print(f"Uzorku {i} ({y_all[i]}): {'Accepted' if accepted else 'Rejected'}")
# Out:
# OD threshold: 0.006501911864453147
# SD threshold: 5.62909053211915
# Uzorku 0 (xvoo_oo10): Rejected
# Uzorku 1 (xvoo_oo10): Rejected
# Uzorku 2 (xvoo_oo10): Rejected
# Uzorku 3 (xvoo_oo10): Rejected
# Uzorku 4 (xvoo_oo10): Rejected
# Uzorku 5 (xvoo_oo10): Rejected
# Uzorku 6 (xvoo_oo10): Rejected
# Uzorku 7 (xvoo_oo10): Rejected
# Uzorku 8 (xvoo_oo10): Rejected
# Uzorku 9 (xvoo_oo10): Rejected
# Uzorku 10 (xvoo_oo10): Rejected
# Uzorku 11 (xvoo_oo10): Rejected
# Uzorku 12 (xvoo_oo10): Rejected
# Uzorku 13 (xvoo_oo10): Rejected
# Uzorku 14 (xvoo_oo10): Rejected
# Uzorku 15 (xvoo_oo10): Rejected
# Uzorku 16 (xvoo_oo10): Rejected
# Uzorku 17 (xvoo_oo10): Rejected
# Uzorku 18 (xvoo_oo10): Rejected
# Uzorku 19 (xvoo_oo10): Rejected
# Uzorku 20 (xvoo_oo10): Rejected
# Uzorku 21 (xvoo_oo10): Rejected
# Uzorku 22 (xvoo_oo10): Rejected
# Uzorku 23 (xvoo_oo10): Rejected
# Uzorku 24 (xvoo_oo10): Rejected
# Uzorku 25 (xvoo_oo10): Rejected
# Uzorku 26 (xvoo_oo10): Rejected
# Uzorku 27 (xvoo_oo10): Rejected
# Uzorku 28 (xvoo_oo10): Rejected
# Uzorku 29 (xvoo_oo10): Rejected
# Uzorku 30 (xvoo_oo20): Rejected
# Uzorku 31 (xvoo_oo20): Rejected
# Uzorku 32 (xvoo_oo20): Rejected
# Uzorku 33 (xvoo_oo20): Rejected
# Uzorku 34 (xvoo_oo20): Rejected
# Uzorku 35 (xvoo_oo20): Rejected
# Uzorku 36 (xvoo_oo20): Rejected
# Uzorku 37 (xvoo_oo20): Rejected
# Uzorku 38 (xvoo_oo20): Rejected
# Uzorku 39 (xvoo_oo20): Rejected
# Uzorku 40 (xvoo_oo20): Rejected
# Uzorku 41 (xvoo_oo20): Rejected
# Uzorku 42 (xvoo_oo20): Rejected
# Uzorku 43 (xvoo_oo20): Rejected
# Uzorku 44 (xvoo_oo20): Rejected
# Uzorku 45 (xvoo_oo20): Rejected
# Uzorku 46 (xvoo_oo20): Rejected
# Uzorku 47 (xvoo_oo20): Rejected
# Uzorku 48 (xvoo_oo20): Rejected
# Uzorku 49 (xvoo_oo20): Rejected
# Uzorku 50 (xvoo_oo20): Rejected
# Uzorku 51 (xvoo_oo20): Rejected
# Uzorku 52 (xvoo_oo20): Rejected
# Uzorku 53 (xvoo_oo20): Rejected
# Uzorku 54 (xvoo_oo20): Rejected
# Uzorku 55 (xvoo_oo20): Rejected
# Uzorku 56 (xvoo_oo20): Rejected
# Uzorku 57 (xvoo_oo20): Rejected
# Uzorku 58 (xvoo_oo20): Rejected
# Uzorku 59 (xvoo_oo20): Rejected
# Uzorku 60 (xvoo_oo30): Rejected
# Uzorku 61 (xvoo_oo30): Rejected
# Uzorku 62 (xvoo_oo30): Rejected
# Uzorku 63 (xvoo_oo30): Rejected
# Uzorku 64 (xvoo_oo30): Rejected
# Uzorku 65 (xvoo_oo30): Rejected
# Uzorku 66 (xvoo_oo30): Rejected
# Uzorku 67 (xvoo_oo30): Rejected
# Uzorku 68 (xvoo_oo30): Rejected
# Uzorku 69 (xvoo_oo30): Rejected
# Uzorku 70 (xvoo_oo30): Rejected
# Uzorku 71 (xvoo_oo30): Rejected
# Uzorku 72 (xvoo_oo30): Rejected
# Uzorku 73 (xvoo_oo30): Rejected
# Uzorku 74 (xvoo_oo30): Rejected
# Uzorku 75 (xvoo_oo30): Rejected
# Uzorku 76 (xvoo_oo30): Rejected
# Uzorku 77 (xvoo_oo30): Rejected
# Uzorku 78 (xvoo_oo30): Rejected
# Uzorku 79 (xvoo_oo30): Rejected
# Uzorku 80 (xvoo_oo30): Rejected
# Uzorku 81 (xvoo_oo30): Rejected
# Uzorku 82 (xvoo_oo30): Rejected
# Uzorku 83 (xvoo_oo30): Rejected
# Uzorku 84 (xvoo_oo30): Rejected
# Uzorku 85 (xvoo_oo30): Rejected
# Uzorku 86 (xvoo_oo30): Rejected
# Uzorku 87 (xvoo_oo30): Rejected
# Uzorku 88 (xvoo_oo30): Rejected
# Uzorku 89 (xvoo_oo30): Rejected
# Uzorku 90 (xvoo_oo40): Rejected
# Uzorku 91 (xvoo_oo40): Rejected
# Uzorku 92 (xvoo_oo40): Rejected
# Uzorku 93 (xvoo_oo40): Rejected
# Uzorku 94 (xvoo_oo40): Rejected
# Uzorku 95 (xvoo_oo40): Rejected
# Uzorku 96 (xvoo_oo40): Rejected
# Uzorku 97 (xvoo_oo40): Rejected
# Uzorku 98 (xvoo_oo40): Rejected
# Uzorku 99 (xvoo_oo40): Rejected
# Uzorku 100 (xvoo_oo40): Rejected
# Uzorku 101 (xvoo_oo40): Rejected
# Uzorku 102 (xvoo_oo40): Rejected
# Uzorku 103 (xvoo_oo40): Rejected
# Uzorku 104 (xvoo_oo40): Rejected
# Uzorku 105 (xvoo_oo40): Rejected
# Uzorku 106 (xvoo_oo40): Rejected
# Uzorku 107 (xvoo_oo40): Rejected
# Uzorku 108 (xvoo_oo40): Rejected
# Uzorku 109 (xvoo_oo40): Rejected
# Uzorku 110 (xvoo_oo40): Rejected
# Uzorku 111 (xvoo_oo40): Rejected
# Uzorku 112 (xvoo_oo40): Rejected
# Uzorku 113 (xvoo_oo40): Rejected
# Uzorku 114 (xvoo_oo40): Rejected
# Uzorku 115 (xvoo_oo40): Rejected
# Uzorku 116 (xvoo_oo40): Rejected
# Uzorku 117 (xvoo_oo40): Rejected
# Uzorku 118 (xvoo_oo40): Rejected
# Uzorku 119 (xvoo_oo40): Rejected
# Uzorku 120 (xvoo_oo60): Rejected
# Uzorku 121 (xvoo_oo60): Rejected
# Uzorku 122 (xvoo_oo60): Rejected
# Uzorku 123 (xvoo_oo60): Rejected
# Uzorku 124 (xvoo_oo60): Rejected
# Uzorku 125 (xvoo_oo60): Rejected
# Uzorku 126 (xvoo_oo60): Rejected
# Uzorku 127 (xvoo_oo60): Rejected
# Uzorku 128 (xvoo_oo60): Rejected
# Uzorku 129 (xvoo_oo60): Rejected
# Uzorku 130 (xvoo_oo60): Rejected
# Uzorku 131 (xvoo_oo60): Rejected
# Uzorku 132 (xvoo_oo60): Rejected
# Uzorku 133 (xvoo_oo60): Rejected
# Uzorku 134 (xvoo_oo60): Rejected
# Uzorku 135 (xvoo_oo60): Rejected
# Uzorku 136 (xvoo_oo60): Rejected
# Uzorku 137 (xvoo_oo60): Rejected
# Uzorku 138 (xvoo_oo60): Rejected
# Uzorku 139 (xvoo_oo60): Rejected
# Uzorku 140 (xvoo_oo60): Rejected
# Uzorku 141 (xvoo_oo60): Rejected
# Uzorku 142 (xvoo_oo60): Rejected
# Uzorku 143 (xvoo_oo60): Rejected
# Uzorku 144 (xvoo_oo60): Rejected
# Uzorku 145 (xvoo_oo60): Rejected
# Uzorku 146 (xvoo_oo60): Rejected
# Uzorku 147 (xvoo_oo60): Rejected
# Uzorku 148 (xvoo_oo60): Rejected
# Uzorku 149 (xvoo_oo60): Rejected
# Uzorku 150 (xvoo_oo70): Rejected
# Uzorku 151 (xvoo_oo70): Rejected
# Uzorku 152 (xvoo_oo70): Rejected
# Uzorku 153 (xvoo_oo70): Rejected
# Uzorku 154 (xvoo_oo70): Rejected
# Uzorku 155 (xvoo_oo70): Rejected
# Uzorku 156 (xvoo_oo70): Rejected
# Uzorku 157 (xvoo_oo70): Rejected
# Uzorku 158 (xvoo_oo70): Rejected
# Uzorku 159 (xvoo_oo70): Rejected
# Uzorku 160 (xvoo_oo70): Rejected
# Uzorku 161 (xvoo_oo70): Rejected
# Uzorku 162 (xvoo_oo70): Rejected
# Uzorku 163 (xvoo_oo70): Rejected
# Uzorku 164 (xvoo_oo70): Rejected
# Uzorku 165 (xvoo_oo70): Rejected
# Uzorku 166 (xvoo_oo70): Rejected
# Uzorku 167 (xvoo_oo70): Rejected
# Uzorku 168 (xvoo_oo70): Rejected
# Uzorku 169 (xvoo_oo70): Rejected
# Uzorku 170 (xvoo_oo70): Rejected
# Uzorku 171 (xvoo_oo70): Rejected
# Uzorku 172 (xvoo_oo70): Rejected
# Uzorku 173 (xvoo_oo70): Rejected
# Uzorku 174 (xvoo_oo70): Rejected
# Uzorku 175 (xvoo_oo70): Rejected
# Uzorku 176 (xvoo_oo70): Rejected
# Uzorku 177 (xvoo_oo70): Rejected
# Uzorku 178 (xvoo_oo70): Rejected
# Uzorku 179 (xvoo_oo70): Rejected
# Uzorku 180 (xvoo_oo80): Rejected
# Uzorku 181 (xvoo_oo80): Rejected
# Uzorku 182 (xvoo_oo80): Rejected
# Uzorku 183 (xvoo_oo80): Rejected
# Uzorku 184 (xvoo_oo80): Rejected
# Uzorku 185 (xvoo_oo80): Rejected
# Uzorku 186 (xvoo_oo80): Rejected
# Uzorku 187 (xvoo_oo80): Rejected
# Uzorku 188 (xvoo_oo80): Rejected
# Uzorku 189 (xvoo_oo80): Rejected
# Uzorku 190 (xvoo_oo80): Rejected
# Uzorku 191 (xvoo_oo80): Rejected
# Uzorku 192 (xvoo_oo80): Rejected
# Uzorku 193 (xvoo_oo80): Rejected
# Uzorku 194 (xvoo_oo80): Rejected
# Uzorku 195 (xvoo_oo80): Rejected
# Uzorku 196 (xvoo_oo80): Rejected
# Uzorku 197 (xvoo_oo80): Rejected
# Uzorku 198 (xvoo_oo80): Rejected
# Uzorku 199 (xvoo_oo80): Rejected
# Uzorku 200 (xvoo_oo80): Rejected
# Uzorku 201 (xvoo_oo80): Rejected
# Uzorku 202 (xvoo_oo80): Rejected
# Uzorku 203 (xvoo_oo80): Rejected
# Uzorku 204 (xvoo_oo80): Rejected
# Uzorku 205 (xvoo_oo80): Rejected
# Uzorku 206 (xvoo_oo80): Rejected
# Uzorku 207 (xvoo_oo80): Rejected
# Uzorku 208 (xvoo_oo80): Rejected
# Uzorku 209 (xvoo_oo80): Rejected
# Uzorku 210 (XVOO_NONE): Accepted
# Uzorku 211 (XVOO_NONE): Accepted
# Uzorku 212 (XVOO_NONE): Accepted
# Uzorku 213 (XVOO_NONE): Accepted
# Uzorku 214 (XVOO_NONE): Accepted
# Uzorku 215 (XVOO_NONE): Accepted
# Uzorku 216 (XVOO_NONE): Rejected
# Uzorku 217 (XVOO_NONE): Accepted
# Uzorku 218 (XVOO_NONE): Accepted
# Uzorku 219 (XVOO_NONE): Accepted

# %%
colors = np.where(res_mix['inside'], 'blue', 'red')

plt.figure(figsize=(8,5))
plt.scatter(res_mix['SD'], res_mix['OD'], c=colors, edgecolor='k')
plt.axhline(ODcrit, color='green', linestyle='--', label='OD threshold')
plt.axvline(SDcrit, color='orange', linestyle='--', label='SD threshold')
plt.xlabel("Score Distance (SD)")
plt.ylabel("Orthogonal Distance (OD)")
plt.title("SIMCA - All xvoo data")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
